# %%
pip install qiskit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import qiskit
from qiskit import * 
import numpy as np
from qiskit.visualization import plot_histogram,plot_state_qsphere ,plot_state_paulivec,plot_state_hinton,plot_state_city,plot_bloch_multivector
from qiskit import QuantumRegister,ClassicalRegister,QuantumCircuit
from qiskit.quantum_info import Statevector,DensityMatrix
from qiskit import IBMQ
from math import pi

# %%
IBMQ.save_account('103fa2853cffe7144841916c04c560df0a0c437da15c45a9fba2b85fecb87c7b2c6e9b310c254fb1db85bff5385f35beb202e9c907578520c9b1e1c2de97ca36')
# Out:
# configrc.store_credentials:WARNING:2022-11-23 21:39:26,680: Credentials already present. Set overwrite=True to overwrite.

# %% [markdown]
# ### Pauli X Gate in ground state |Φ>=(1,0)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
plot_state_qsphere(qc)

# %%
rho1 = DensityMatrix(qc)
rho1.draw('latex',prefix='\\rho_1 = ')
# Out:
# $$
# \rho_1 =
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_state_city(qc)

# %%
plot_state_hinton(qc)

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I+1/2*Pauli_z

# %%
plot_bloch_multivector(qc)

# %%
purity = rho1.purity()
print(purity)       #purity=Trace(Density_matrix*Density_matrix)
# Out:
# (1+0j)

# %%
qc.x(q[0])

# %%
qc.draw()
# Out:
#      ┌───┐
# q12: ┤ X ├
#      └───┘
# c12: ═════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  # flips the ground state
# Out:
# $$ |1\rangle$$

# %%
plot_state_qsphere(qc)

# %%
rhox = DensityMatrix(qc)
rhox.draw('latex',prefix='\\rho_x=')
# Out:
# $$
# \rho_x=
# \begin{bmatrix}
# 0 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I-1/2*Pauli_z

# %%
plot_bloch_multivector(qc)

# %%
purityf = rhox.purity()
print(purityf)
# Out:
# (1+0j)

# %%
qc.measure(q[0],c[0])

# %%
qc.draw()
# Out:
#      ┌───┐┌─┐
# q12: ┤ X ├┤M├
#      └───┘└╥┘
# c12: ══════╩═

# %% [markdown]
# ### Pauli Y Gate in ground state |Φ>=(1,0)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
qc.y(q[0])

# %%
qc.draw()
# Out:
#      ┌───┐
# q13: ┤ Y ├
#      └───┘
# c13: ═════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  ## has a global phase of 'i'
# Out:
# $$i |1\rangle$$

# %%
plot_state_qsphere(qc)   ## flips the ground state

# %%
rhoy = DensityMatrix(qc)
rhoy.draw('latex',prefix='\\rho_y=')
# Out:
# $$
# \rho_y=
# \begin{bmatrix}
# 0 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I-1/2*Pauli_z

# %%
plot_bloch_multivector(qc)

# %%
purityf = rhoy.purity()
print(purityf)
# Out:
# (1+0j)

# %%
qc.draw()
# Out:
#      ┌───┐
# q13: ┤ Y ├
#      └───┘
# c13: ═════

# %% [markdown]
# ### Pauli Y Gate in ground state |Φ>=(1,0)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
qc.z(q[0])

# %%
qc.draw()
# Out:
#      ┌───┐
# q14: ┤ Z ├
#      └───┘
# c14: ═════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  ## kind of obvious doesn't chane it state
# Out:
# $$ |0\rangle$$

# %%
plot_state_qsphere(qc)   ## doesn't change

# %%
rhoz = DensityMatrix(qc)
rhoz.draw('latex',prefix='\\rho_z=')
# Out:
# $$
# \rho_z=
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I+1/2*Pauli_z

# %%
plot_bloch_multivector(qc)

# %%
purityf = rhoz.purity()
print(purityf)
# Out:
# (1+0j)

# %%
qc.measure(q[0],c[0])

# %%
qc.draw()
# Out:
#      ┌───┐┌─┐
# q14: ┤ Z ├┤M├
#      └───┘└╥┘
# c14: ══════╩═

# %% [markdown]
# ### hadamard Gate in ground state |Φ>=(1,0)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
qc.h(q[0])

# %%
qc.draw()
# Out:
#      ┌───┐
# q15: ┤ H ├
#      └───┘
# c15: ═════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  ## change to 'x+'
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
plot_state_qsphere(qc)

# %%
rhoh = DensityMatrix(qc)
rhoh.draw('latex',prefix='\\rho_h=')
# Out:
# $$
# \rho_h=
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I+1/2*Pauli_X

# %%
plot_bloch_multivector(qc) #(1,0,0) direction

# %%
purityf = rhoz.purity()
print(purityf)  ## norm is unit hence purity should be 1
# Out:
# (1+0j)

# %%
qc.measure(q[0],c[0])

# %%
qc.draw()
# Out:
#      ┌───┐┌─┐
# q15: ┤ H ├┤M├
#      └───┘└╥┘
# c15: ══════╩═

# %% [markdown]
# ### Rx Gate in ground state |Φ>=(1,0) with θ=Π/2

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
qc.rx(pi/2,q[0])

# %%
qc.draw()
# Out:
#      ┌─────────┐
# q16: ┤ Rx(π/2) ├
#      └─────────┘
# c16: ═══════════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  ## change to 'y-'
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2} i}{2} |1\rangle$$

# %%
plot_state_qsphere(qc)

# %%
rhorx = DensityMatrix(qc)
rhorx.draw('latex',prefix='\\rho_{rx}=')
# Out:
# $$
# \rho_{rx}=
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}i  \\
#  -\tfrac{1}{2}i & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I-1/2*Pauli_Y

# %%
plot_bloch_multivector(qc) #(0,-1,0) direction

# %%
purityf = rhoz.purity()
print(purityf)  ## norm is unit hence purity should be 1
# Out:
# (1+0j)

# %%
qc.measure(q[0],c[0])

# %%
qc.draw()
# Out:
#      ┌─────────┐┌─┐
# q16: ┤ Rx(π/2) ├┤M├
#      └─────────┘└╥┘
# c16: ════════════╩═

# %% [markdown]
# ### Ry Gate in ground state |Φ>=(1,0) with θ=Π/2

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
qc.ry(pi/2,q[0])

# %%
qc.draw()
# Out:
#      ┌─────────┐
# q17: ┤ Ry(π/2) ├
#      └─────────┘
# c17: ═══════════

# %%
psi2 = Statevector(qc)
psi2.draw('latex')  ## change to 'x+'
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
plot_state_qsphere(qc)

# %%
rhory = DensityMatrix(qc)
rhory.draw('latex',prefix='\\rho_{ry}=')
# Out:
# $$
# \rho_{ry}=
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
plot_state_paulivec(qc, title = 'Density matrix of the final state as linear combination of Pauli Gates') #Density_matrix=1/2*I+1/2*Pauli_x

# %%
plot_bloch_multivector(qc) #(1,0,0) direction

# %%
qc.measure(q[0],c[0])

# %%
qc.draw()
# Out:
#      ┌─────────┐┌─┐
# q17: ┤ Ry(π/2) ├┤M├
#      └─────────┘└╥┘
# c17: ════════════╩═

# %%
#it is quite obvious Rz doesn't change state
